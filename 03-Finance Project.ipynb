# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Google finance using pandas!
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# *Note: [You'll need to install pandas-datareader for this to work!](https://github.com/pydata/pandas-datareader) Pandas datareader allows you to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**), or just follow along with the video lecture.*
#
# ### The Imports
#
# Already filled out for you.

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
from datetime import datetime
import seaborn as sns
# %matplotlib inline
#pk_81d39227b9234d888a69e05b0b5ba434

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Figure out how to get the stock data from Jan 1st 2009 to Jan 1st 2019 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
# ** Use [this documentation page](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) for hints and instructions (it should just be a matter of replacing certain values. Use google finance as a source, for example:**
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)
#
# ### WARNING: MAKE SURE TO CHECK THE LINK ABOVE FOR THE LATEST WORKING API. "google" MAY NOT ALWAYS WORK.
# ------------

# %%
#Bank of America: BAC
#Citigroup: C
#Goldman Sachs: GS
#JPMorgan Chase: JPM
#Morgan Stanley: MS
#Wells Fargo: WFC
import os
os.environ["IEX_API_KEY"]="pk_81d39227b9234d888a69e05b0b5ba434"
start=datetime(2009, 1, 1)
end=datetime(2019, 1, 1)

# %%
BAC=data.DataReader('BAC','iex',start,end)

# %%
GS=data.DataReader('GS','iex',start,end)

# %%
JPM=data.DataReader('JPM','iex',start,end)

# %%
C=data.DataReader('C','iex',start,end)

# %%
MS=data.DataReader('MS','iex',start,end)

# %%
WFC=data.DataReader('WFC','iex',start,end)

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
tickers=['BAC','C','GS','JPM','MS','WFC']

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
bank_stocks=pd.concat([BAC,JPM,C,WFC,GS,MS],axis=1,keys=tickers)

# %% [markdown]
# ** Set the column name levels (this is filled out for you):**

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# ** Check the head of the bank_stocks dataframe.**

# %%
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                          C                \
# Stock Info    open   high      low  close       volume   open   high    low
# date
# 2009-01-02   13.92  14.57  13.7100  14.33   86647269.0  31.26  31.64  30.47
# 2009-01-05   14.38  14.55  13.8900  13.98   93725651.0  30.60  30.72  29.08
# 2009-01-06   14.27  14.81  14.0700  14.28  111069086.0  29.76  30.42  29.51
# 2009-01-07   14.11  14.13  13.6100  13.71  112887266.0  29.10  29.40  28.00
# 2009-01-08   13.82  13.99  13.3482  13.54   93943479.0  27.78  27.95  26.86
#
# Bank Ticker                   ...     MS                                   \
# Stock Info   close    volume  ...   open   high      low  close    volume
# date                          ...
# 2009-01-02   31.35   7740500  ...  84.02  87.62  82.1900  86.76  14139228
# 2009-01-05   29.25  10446600  ...  85.81  90.95  85.4600  88.78  16009641
# 2009-01-06   29.88   9557500  ...  90.05  92.20  87.7200  88.71  21555887
# ...

# %%
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker             ...        MS                                  WFC  \
# Stock Info    Volume    ...      Open   High    Low  Close   Volume   Open
# Date                    ...
# 2006-01-03   1537660    ...     57.17  58.49  56.74  58.31  5377000  31.60
# 2006-01-04   1871020    ...     58.70  59.28  58.35  58.35  7977800  31.80
# 2006-01-05   1143160    ...     58.55  58.59  58.02  58.51  5778000  31.50
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit! Before continuing, I encourage you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Reference the solutions if you can not figure out how to use .xs(), since that will be a major part of this project.
#
# ** What is the max Close price for each bank's stock throughout the time period?**

# %%
bank_stocks.loc[:,(slice(None),'close')].max()
# Out:
# BAC  close     32.84
# C    close    118.77
# GS   close     80.08
# JPM  close     65.93
# MS   close    273.38
# WFC  close     58.91
# dtype: float64

# %%
for tick in tickers:
    print(tick,bank_stocks[tick]['close'].max())
# Out:
# BAC 32.84
# C 118.77
# GS 80.08
# JPM 65.93
# MS 273.38
# WFC 58.91

# %%
#xs(cross section used to get keys out of columns or rows)
bank_stocks.xs(key='close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     32.84
# C      118.77
# GS      80.08
# JPM     65.93
# MS     273.38
# WFC     58.91
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns=pd.DataFrame()
returns
retro=pd.DataFrame()

# %% [markdown]
# ** We can use pandas pct_change() method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
ray=bank_stocks.pct_change().loc[:,(slice(None),'close')]
ray.columns
for i in ray.columns:
    returns[i[0]]=ray[i][:]

returns
# Out:
#                  BAC         C        GS       JPM        MS       WFC
# date
# 2009-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2009-01-05 -0.024424 -0.066986 -0.008403 -0.064667  0.023283  0.037081
# 2009-01-06  0.021459  0.021538  0.053672 -0.018532 -0.000788  0.111237
# 2009-01-07 -0.039916 -0.059906 -0.041555 -0.060639 -0.047458 -0.075587
# 2009-01-08 -0.012400 -0.030972  0.001399 -0.005798  0.010769  0.039779
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-31  0.010250  0.008159  0.004438  0.006553  0.024658  0.007112
# 2014-08-13  0.000000 -0.418972  0.000000  0.084852  0.031847 -0.192434
# 2014-08-19  0.000000  0.014810  0.000000  0.017403  0.009224  0.015928
# 2014-08-21  0.000000  0.016331  0.000000  0.008455  0.006841  0.015370
# 2014-11-27  0.000000  0.031453  0.000000  0.058296  0.076335  0.063276
#
# [2527 rows x 6 columns]

# %%
for tick in tickers:
    retro[tick+' return']=bank_stocks[tick]['close'].pct_change()

retro.head()
# Out:
#             BAC return  C return  GS return  JPM return  MS return  WFC return
# date
# 2009-01-02         NaN       NaN        NaN         NaN        NaN         NaN
# 2009-01-05   -0.024424 -0.066986  -0.008403   -0.064667   0.023283    0.037081
# 2009-01-06    0.021459  0.021538   0.053672   -0.018532  -0.000788    0.111237
# 2009-01-07   -0.039916 -0.059906  -0.041555   -0.060639  -0.047458   -0.075587
# 2009-01-08   -0.012400 -0.030972   0.001399   -0.005798   0.010769    0.039779

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
sns.pairplot(data=returns)
# Out:
# c:\Users\markanthony\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# * See solution for details about Citigroup behavior....

# %% [markdown]
# ** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
#idxmax(returns the row with the maximum value,all the data set)
#argmin(return time stamp,each column )
returns.idxmax(),returns.idxmin()
# Out:
# (BAC    2009-04-09
#  C      2009-01-21
#  GS     2009-03-10
#  JPM    2009-04-09
#  MS     2009-01-21
#  WFC    2009-01-21
#  dtype: object,
#  BAC    2009-01-20
#  C      2014-08-13
#  GS     2009-02-27
#  JPM    2009-01-20
#  MS     2009-01-20
#  WFC    2014-08-13
#  dtype: object)

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %% [markdown]
# * See Solution for details

# %% [markdown]
# ** Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
returns.std()
returns2=returns.reset_index()
ret=returns2[(returns2['date'].apply(lambda x:x.split('-')[0]))=='2015'][['BAC','C','GS','JPM','MS','WFC']].std()

# %%
returns.loc['2015-01-02':'2015-12-31'].std()
# Out:
# BAC    0.016163
# C      0.014017
# GS     0.015289
# JPM    0.012591
# MS     0.014046
# WFC    0.016249
# dtype: float64

# %% [markdown]
# ** Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
sns.distplot(returns2[(returns2['date'].apply(lambda x:x.split('-')[0]))=='2015']['MS'])
# Out:
# C:\Users\markanthony\AppData\Local\Temp\ipykernel_15140\564998321.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(returns2[(returns2['date'].apply(lambda x:x.split('-')[0]))=='2015']['MS'])
# <Axes: xlabel='MS', ylabel='Density'>

# %%
sns.distplot(retro.loc['2015-01-02':'2015-12-31']['MS return'],color='green',bins=60)
# Out:
# C:\Users\markanthony\AppData\Local\Temp\ipykernel_15140\409869362.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(retro.loc['2015-01-02':'2015-12-31']['MS return'],color='green',bins=60)
# <Axes: xlabel='MS return', ylabel='Density'>

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
sns.distplot(returns2[(returns2['date'].apply(lambda x:x.split('-')[0]))=='2009']['C'])
# Out:
# C:\Users\markanthony\AppData\Local\Temp\ipykernel_15140\3672766119.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(returns2[(returns2['date'].apply(lambda x:x.split('-')[0]))=='2009']['C'])
# <Axes: xlabel='C', ylabel='Density'>

# %%
sns.distplot(retro.loc['2009-01-02':'2009-12-31']['C return'],color='red',bins=50)
# Out:
# C:\Users\markanthony\AppData\Local\Temp\ipykernel_15140\3735104297.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='C return', ylabel='Density'>

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
(bank_stocks.xs(key='close',axis=1,level='Stock Info')).plot(figsize=(12,4))
plt.legend()

# %%
for tick in tickers:
    bank_stocks[tick]['close'].plot(label=tick,figsize=(12,4))
    plt.legend()

# %%
bank_stocks.xs(key='close',axis=1,level='Stock Info').iplot()
# Out:
# <div>                            <div id="b02b13d3-be99-4776-b8d2-e657f7629aa2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
reliance=bank_stocks['BAC']['close'].to_frame()
reliance['SMA30']=reliance['close'].rolling(30).mean()
reliance.dropna(inplace=True)
reliance
# Out:
#             close      SMA30
# date
# 2009-02-12   5.87   8.204333
# 2009-02-13   5.57   7.912333
# 2009-02-17   4.90   7.609667
# 2009-02-18   4.57   7.286000
# 2009-02-19   3.93   6.960000
# ...           ...        ...
# 2018-12-24  22.73  26.324667
# 2018-12-26  24.11  26.177667
# 2018-12-27  24.37  26.065000
# 2018-12-28  24.39  25.952667
# 2018-12-31  24.64  25.867000
#
# [2494 rows x 2 columns]

# %%
plt.figure(figsize=(12,4))
BAC['close'].loc['2009-01-02':'2010-01-01'].rolling(window=30).mean().plot(label='30 Day Mov Avg')
BAC['close'].loc['2009-01-02':'2010-01-01'].plot(label='BAC Close')
plt.legend()

# %%
reliance[['close','SMA30']].plot(label='RELIANCE',figsize=(16,8))
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
sns.heatmap(data=returns.corr(),annot=True)
# Out:
# <Axes: >

# %%
#annot(shows the values on the map)
sns.heatmap(bank_stocks.xs(key='close',axis=1,level='Stock Info').corr(),annot=True)
# Out:
# <Axes: xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# ** Optional: Use seaborn's clustermap to cluster the correlations together:**

# %%
sns.clustermap(data=returns.corr(),annot=True)

# %%
sns.clustermap(bank_stocks.xs(key='close',axis=1,level='Stock Info').corr(),annot=True)

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
bank_stocks['BAC'][['open','high','low','close']].loc['2015-01-02':'2016-01-04'].iplot(kind='candle')
# Out:
# <div>                            <div id="dbe4c243-5356-4f80-bc69-5ee1ef1eda2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
bank_stocks['MS'][['open','high','low','close']]['2015-01-02':'2015-12-31'].ta_plot(study='sma')
# Out:
# <div>                            <div id="f3b7bb5b-0ba2-4030-8428-61975dc15c6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
bank_stocks['BAC']['close']['2015-01-02':'2015-12-31'].ta_plot(study='boll')
# Out:
# <div>                            <div id="d44e384c-c600-4c1e-b634-2c62a1ee5414" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Great Job!
#
# Definitely a lot of more specific finance topics here, so don't worry if you didn't understand them all! The only thing you should be concerned with understanding are the basic pandas and visualization oeprations.
